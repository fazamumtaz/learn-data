# %% [markdown]
# # Import Seaborn

# %%
import seaborn as sns

# %% [markdown]
# # Import Data from Seaborn

# %%
titanic = sns.load_dataset('titanic')
titanic.shape
# Out:
# (891, 15)

# %% [markdown]
# # Univariate Analysis (Focusing on 1 Variable)

# %% [markdown]
# 1. Continous Plots
#    + Histogram
#    + Boxplot
#    + Boxenplot
#    + Rugplot
#    + Violinplot
#    + KDE plot
#    + Strip plot
# 2. Categorical Plots
#    + Countplot

# %% [markdown]
# ## Continous Plots

# %%
penguins = sns.load_dataset('penguins')
gold = sns.load_dataset('diamonds')
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# ### Histogram

# %% [markdown]
# Argumen yang bisa diterima `sns.histplot()`:
#
# * **bins**: Untuk menentukan jumlah bin (interval).
# * **binwidth**: Menentukan lebar bin.
# * **kde**: Menambahkan kurva KDE (Kernel Density Estimation).
# * **hue**: Membagi data berdasarkan kategori.
# * **multiple**: Cara menampilkan hue.
# * **element**: Mengontrol tampilan bar (bars(default), step(garis tepi saja))
# * **stat**: Mengubah skala histogram.

# %%
sns.histplot(penguins, x='body_mass_g', bins=20, binwidth=200, kde=True, color='#48A6A7')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
sns.histplot(penguins, x='body_mass_g', hue='species', multiple='stack', element='bars', fill=True, palette='Set2')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %% [markdown]
# **Penjelasan:**
#  + **hue:** mengelompokkan berdasarkan species penguin
#  + **multiple:**
#    + **layer:**  saling menutupi satu sama lain (berisiko tidak terlihat)
#    + **stack:** bertingkat
#    + **dodge:** terpisah setiap kategori
# + **element:** bar(default), step(outline setiap graph)
# + **fill:** True(default), False(graph with outline only)

# %%
sns.histplot(penguins, x='body_mass_g', stat='frequency', shrink=0.8)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Frequency'>

# %% [markdown]
# **Penjelasan:**
# + **"count"** → Jumlah data (default).
# + **"density"** → Normalisasi sehingga total luasnya = 1.
# + **"probability"** → Setiap bar mewakili probabilitasnya.

# %% [markdown]
# ### Boxplot (box-and-whisker-plot):

# %% [markdown]
# Boxplot menggambarkan ringkasan statistik 5 angka (Five Number Summary) dalam satu grafik:
#
# + **Min (minimum)** → Nilai terkecil (batas bawah tanpa outlier)
# + **Q1 (Kuartil 1)** → Nilai 25% data terendah
# + **Median (Q2)** → Nilai tengah data
# + **Q3 (Kuartil 3)** → Nilai 75% data terendah
# + **Max (maximum)** → Nilai terbesar (batas atas tanpa outlier)
# + **Outlier** → Ditampilkan sebagai titik di luar whisker jika data terlalu jauh dari Q1 atau Q3.
#
# Argumen yang diterima:
# + **fliersize:** ukuran lingkaran outliers, 5 default dan 0 artinya tidak terlihat
# + **showfliers:** False(outliers tidak terlihat), True(outliers terlihat)
# + **x, y:** pengelompokan apabila x dan y diatur
# + **showmeans:** menunjukkan titik mean data
# + **meanprops:** styling titik mean
# + **linewidth:** ketebalan garis boxplot
# + **whis:** mengatur panjang boxplot

# %%
sns.boxplot(data=penguins, x='body_mass_g', width=0.2, color='#48A6A7')
# Out:
# <Axes: xlabel='body_mass_g'>

# %%
sns.boxplot(data=penguins, y='species', 
            x='body_mass_g', width=0.2, 
            color='#48A6A7', fliersize=2, showfliers=False)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='species'>

# %%
sns.boxplot(data=penguins, y='species', 
            x='body_mass_g', width=0.2, 
            color='#48A6A7', showmeans=True,
            meanprops={"marker":"o", "markerfacecolor":"red", "markeredgecolor":"black"})
# Out:
# <Axes: xlabel='body_mass_g', ylabel='species'>

# %%
sns.boxplot(data=penguins, y='species', 
            x='body_mass_g', width=0.2, 
            color='#48A6A7', notch=True,
            linewidth=2)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='species'>

# %% [markdown]
# ### Boxenplot

# %%
sns.boxenplot(data=penguins, x='body_mass_g', width_method='linear', color='#48A6A7')
# Out:
# <Axes: xlabel='body_mass_g'>

# %% [markdown]
# ### Violinplot

# %%
sns.violinplot(y="body_mass_g", data=penguins, hue="sex", split=True, density_norm='width')
# Out:
# <Axes: ylabel='body_mass_g'>

# %%
sns.violinplot(y=penguins["body_mass_g"], inner="point", bw_method=1)
# Out:
# <Axes: ylabel='body_mass_g'>

# %% [markdown]
# ### rugplot

# %%
sns.rugplot(x="body_mass_g", data=penguins, hue="species")
# Out:
# <Axes: xlabel='body_mass_g'>

# %% [markdown]
# ## Categorical Plots

# %% [markdown]
# ### Countplot

# %%
sns.countplot(data=titanic, x='sex', hue='alive', hue_order=['yes', 'no'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>
