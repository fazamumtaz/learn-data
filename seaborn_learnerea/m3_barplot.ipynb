# %% [markdown]
# # 1. Setup Library

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# # 2. Load Dataset

# %%
sales = pd.read_excel('../dataset/supermarket_sales.xlsx')
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # 3. Creating a barplot

# %%
plt.figure(figsize=(15,5))
sns.barplot(sales, x='Product line', y='Total', hue='Product line')
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %% [markdown]
# # 4. Add hue to barplot

# %%
plt.figure(figsize=(15,5))
sns.barplot(sales, x='Product line', y='Total', hue='Gender')
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %% [markdown]
# # 5. Create a Horizontal Barplot

# %%
plt.figure(figsize=(15,5))
sns.barplot(sales, y='Product line', x='Total', hue='Product line')
# Out:
# <Axes: xlabel='Total', ylabel='Product line'>

# %% [markdown]
# # 6. Style in the given order

# %%
# Get the Alphabetically ordered
# sales['Product line'].sort_values().unique()
plt.figure(figsize=(15, 5))
sns.barplot(sales, x='Product line', y='Total', hue='Product line', order=['Electronic_accessories', 'Fashion_accessories',
       'Food_and_beverages', 'Health_and_beauty', 'Home_and_lifestyle',
       'Sports_and_travel'])
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %% [markdown]
# # 7. Changing the Hue order

# %%
plt.figure(figsize=(15, 5))
sns.barplot(sales, x='Product line', y='Total', hue='Gender', hue_order=['Male', 'Female'])
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %% [markdown]
# # 8. Styling cap of the ERROR bar

# %%
plt.figure(figsize=(15, 5))
csns.barplot(sales, x='Product line', y='Total', hue='Gender', hue_order=['Male', 'Female'], capsize=0.2)
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %% [markdown]
# # 9. Removing the ERROR BAR

# %%
plt.figure(figsize=(15, 5))
sns.barplot(sales, x='Product line', y='Total', hue='Gender', hue_order=['Male', 'Female'], errorbar=None)
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %% [markdown]
# # 10. Styling bar color using COLOR

# %%
plt.figure(figsize=(15, 5))
sns.barplot(sales, x='Product line', y='Total', hue='Gender', hue_order=['Male', 'Female'], errorbar=None,
            palette='cividis')
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %% [markdown]
# # 10. SATURATION attribute

# %%
plt.figure(figsize=(15, 5))
sns.barplot(sales, x='Product line', y='Total', hue='Gender', hue_order=['Male', 'Female'], errorbar=None,
            palette='cividis',
            saturation=10)
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>
